# %%
# Import modules.
import pandas as pd
import numpy as np
import seaborn as sns
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the dataset.
df = pd.read_csv('./data/WELLCOME_APCspend2013_forThinkful.csv', encoding = "ISO-8859-1")
df.head()
#df.shape
#df.columns
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
# Make the data lowercase.
df = df.apply(lambda x: x.astype(str).str.lower())
#df.sort_values(['Journal title'], ascending=True)
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    nan       cup  psychological medicine
# 1             pmc3679557       acs       biomacromolecules
# 2  23043264  pmc3506128        acs              j med chem
# 3    23438330 pmc3646402       acs              j med chem
# 4   23438216 pmc3601604        acs              j org chem
#
#                                        Article title  \
# 0  reduced parahippocampal cortical thickness in ...
# 1  structural characterization of a model gram-ne...
# 2  fumaroylamino-4,5-epoxymorphinans and related ...
# 3  orvinols with mixed kappa/mu opioid receptor a...
# 4  regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
df['Journal title'] = df['Journal title'].replace(['', ''], '')
df['Journal title'] = df['Journal title'].replace(['', ''], '')

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    nan       cup  psychological medicine
# 1             pmc3679557       acs       biomacromolecules
# 2  23043264  pmc3506128        acs              j med chem
# 3    23438330 pmc3646402       acs              j med chem
# 4   23438216 pmc3601604        acs              j org chem
#
#                                        Article title  \
# 0  reduced parahippocampal cortical thickness in ...
# 1  structural characterization of a model gram-ne...
# 2  fumaroylamino-4,5-epoxymorphinans and related ...
# 3  orvinols with mixed kappa/mu opioid receptor a...
# 4  regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
# Removing blank spaces in Journal title
df['Journal ']

# %%
df.apply(lambda x: str(x).isdigit())
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-1-f3e5c05a3cc6> in <module>()
# ----> 1 df.apply(lambda x: str(x).isdigit())
#
# NameError: name 'df' is not defined

# %%
# Determine the 5 most common journals and the total articles for each.
df['Journal title'].value_counts()[:5]
df['Journal title'].value_counts().head(5)
# Out:
# plos one                           190
# journal of biological chemistry     53
# neuroimage                          29
# plos genetics                       24
# plos pathogens                      24
# Name: Journal title, dtype: int64

# %%
# Then calc mean, median, std dev of open-access cost per article for each journal.
df.describe()
# Out:
#        PMID/PMCID Publisher Journal title  \
# count        2127      2127          2127
# unique       1878       275           929
# top           nan  elsevier      plos one
# freq          199       391           190
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %%
# Bonus: identify the open access prices paid by subject area.
