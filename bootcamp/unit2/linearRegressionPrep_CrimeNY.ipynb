# %% [markdown]
# # NY Crime Data Prep

# %%
# Import modules.

# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn import linear_model

# Suppress error.
import warnings
warnings.filterwarnings(action='ignore', module='scipy',
                       message='^internal gelsd')

# %%
# Load data.

df = pd.read_csv('~/src/data/unit2/nycrimedata.csv')
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (348, 13)
# City                                       object
# Population                                  int64
# Violent\ncrime                              int64
# Murder and\nnonnegligent\nmanslaughter      int64
# Rape\n(revised\ndefinition)1              float64
# Rape\n(legacy\ndefinition)2                 int64
# Robbery                                     int64
# Aggravated\nassault                         int64
# Property\ncrime                             int64
# Burglary                                    int64
# Larceny-\ntheft                             int64
# Motor\nvehicle\ntheft                       int64
# Arson3                                    float64
# dtype: object
#                        City  Population  Violent\ncrime  \
# 0             Adams Village        1861               0
# 1  Addison Town and Village        2577               3
# 2             Akron Village        2846               3
# 3                    Albany       97956             791
# 4            Albion Village        6388              23
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                       0                           NaN
# 1                                       0                           NaN
# 2                                       0                           NaN
# 3                                       8                           NaN
# 4                                       0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                            0        0                    0               12
# 1                            0        0                    3               24
# 2                            0        0                    3               16
# 3                           30      227                  526             4090
# 4                            3        4                   16              223
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3
# 0         2               10                      0     0.0
# 1         3               20                      1     0.0
# 2         1               15                      0     0.0
# 3       705             3243                    142     NaN
# 4        53              165                      5     NaN

# %%
df.describe()
# Out:
#          Population  Violent\ncrime  Murder and\nnonnegligent\nmanslaughter  \
# count  3.480000e+02      348.000000                              348.000000
# mean   4.003763e+04      201.594828                                1.566092
# std    4.500374e+05     2815.268504                               18.303673
# min    5.260000e+02        0.000000                                0.000000
# 25%    3.003000e+03        2.000000                                0.000000
# 50%    7.233500e+03        6.000000                                0.000000
# 75%    1.842750e+04       22.000000                                0.000000
# max    8.396126e+06    52384.000000                              335.000000
#
#        Rape\n(revised\ndefinition)1  Rape\n(legacy\ndefinition)2  \
# count                           0.0                   348.000000
# mean                            NaN                     5.864943
# std                             NaN                    60.425452
# min                             NaN                     0.000000
# 25%                             NaN                     0.000000
# 50%                             NaN                     0.000000
# 75%                             NaN                     2.000000
# max                             NaN                  1112.000000
#
#             Robbery  Aggravated\nassault  Property\ncrime      Burglary  \
# count    348.000000           348.000000       348.000000    348.000000
# mean      72.902299           121.261494       792.606322    119.683908
# std     1031.032873          1706.131730      7659.724746    924.948789
# min        0.000000             0.000000         0.000000      0.000000
# 25%        0.000000             1.000000        40.500000      6.000000
# 50%        1.000000             4.000000       112.500000     17.500000
# 75%        5.000000            14.000000       341.000000     51.250000
# max    19170.000000         31767.000000    141971.000000  16606.000000
#
#        Larceny-\ntheft  Motor\nvehicle\ntheft      Arson3
# count       348.000000             348.000000  187.000000
# mean        637.017241              35.905172    1.871658
# std        6346.054451             403.423826   10.693411
# min           0.000000               0.000000    0.000000
# 25%          31.000000               0.000000    0.000000
# 50%          94.000000               2.000000    0.000000
# 75%         287.250000               7.000000    1.000000
# max      117931.000000            7434.000000  132.000000

# %% [markdown]
# ## Clean the data:

# %%
df.columns = ['city', 'population', 'violent_crime', 'murder', 'rape_1',
              'rape_2', 'robbery', 'aggravated_assault', 'property_crime',
              'burglary', 'larceny_theft', 'motor_vehicle_theft', 'arson3']
df.tail()
# Out:
#                   city  population  violent_crime  murder  rape_1  rape_2  \
# 343      Woodbury Town       10685              3       0     NaN       0
# 344  Woodridge Village         829              7       0     NaN       0
# 345     Woodstock Town        5931              2       0     NaN       0
# 346            Yonkers      199134           1036       6     NaN      25
# 347      Yorktown Town       36643             15       0     NaN       0
#
#      robbery  aggravated_assault  property_crime  burglary  larceny_theft  \
# 343        2                   1             541         9            529
# 344        0                   7              17         8              9
# 345        0                   2              58        13             45
# 346      390                 615            2368       470           1662
# 347        2                  13             334        45            287
#
#      motor_vehicle_theft  arson3
# 343                    3     NaN
# 344                    0     0.0
# 345                    0     NaN
# 346                  236    10.0
# 347                    2     NaN

# %%
df.isnull().sum()
# Out:
# city                     0
# population               0
# violent_crime            0
# murder                   0
# rape_1                 348
# rape_2                   0
# robbery                  0
# aggravated_assault       0
# property_crime           0
# burglary                 0
# larceny_theft            0
# motor_vehicle_theft      0
# arson3                 161
# dtype: int64

# %%
df = df.drop(['rape_1'], axis=1)
df.tail()
# Out:
#                   city  population  violent_crime  murder  rape_2  robbery  \
# 343      Woodbury Town       10685              3       0       0        2
# 344  Woodridge Village         829              7       0       0        0
# 345     Woodstock Town        5931              2       0       0        0
# 346            Yonkers      199134           1036       6      25      390
# 347      Yorktown Town       36643             15       0       0        2
#
#      aggravated_assault  property_crime  burglary  larceny_theft  \
# 343                   1             541         9            529
# 344                   7              17         8              9
# 345                   2              58        13             45
# 346                 615            2368       470           1662
# 347                  13             334        45            287
#
#      motor_vehicle_theft  arson3
# 343                    3     NaN
# 344                    0     0.0
# 345                    0     NaN
# 346                  236    10.0
# 347                    2     NaN

# %%
df.fillna(0, inplace=True)
df.isnull().sum()
#df.tail()
# Out:
# city                   0
# population             0
# violent_crime          0
# murder                 0
# rape_2                 0
# robbery                0
# aggravated_assault     0
# property_crime         0
# burglary               0
# larceny_theft          0
# motor_vehicle_theft    0
# arson3                 0
# dtype: int64

# %% [markdown]
# ## Creating categorical features:

# %% [markdown]
# $$ Property crime = \alpha + Population + Population^2 + Murder + Robbery$$ <br>

# %%
df['populationSquared'] = df['population']*df['population']
df.head()
# Out:
#                        city  population  violent_crime  murder  rape_2  \
# 0             Adams Village        1861              0       0       0
# 1  Addison Town and Village        2577              3       0       0
# 2             Akron Village        2846              3       0       0
# 3                    Albany       97956            791       8      30
# 4            Albion Village        6388             23       0       3
#
#    robbery  aggravated_assault  property_crime  burglary  larceny_theft  \
# 0        0                   0              12         2             10
# 1        0                   3              24         3             20
# 2        0                   3              16         1             15
# 3      227                 526            4090       705           3243
# 4        4                  16             223        53            165
#
#    motor_vehicle_theft  arson3  populationSquared
# 0                    0     0.0            3463321
# 1                    1     0.0            6640929
# 2                    0     0.0            8099716
# 3                  142     0.0         9595377936
# 4                    5     0.0           40806544

# %%
df['murder_cat'] = df['murder'].apply(lambda x: 1 if x > 0 else 0)
df['robbery_cat'] = df['robbery'].apply(lambda x: 1 if x > 0 else 0)
df.head()
# Out:
#                        city  population  violent_crime  murder  rape_2  \
# 0             Adams Village        1861              0       0       0
# 1  Addison Town and Village        2577              3       0       0
# 2             Akron Village        2846              3       0       0
# 3                    Albany       97956            791       8      30
# 4            Albion Village        6388             23       0       3
#
#    robbery  aggravated_assault  property_crime  burglary  larceny_theft  \
# 0        0                   0              12         2             10
# 1        0                   3              24         3             20
# 2        0                   3              16         1             15
# 3      227                 526            4090       705           3243
# 4        4                  16             223        53            165
#
#    motor_vehicle_theft  arson3  populationSquared  murder_cat  robbery_cat
# 0                    0     0.0            3463321           0            0
# 1                    1     0.0            6640929           0            0
# 2                    0     0.0            8099716           0            0
# 3                  142     0.0         9595377936           1            1
# 4                    5     0.0           40806544           0            1
